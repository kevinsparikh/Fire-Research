# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data1.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
g = df.groupby('State')

# %%
type(g)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# %matplotlib inline

statesList = df.groupby('State')
print(statesList)
#df[['Date','Fire Name']].groupby('Date').count.plot()

# %%
statesList = df.groupby('State')
statesList.head()
import matplotlib.pyplot as plt

# %%
len(AL_Fires)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a1ce71cdf58d> in <module>
# ----> 1 len(AL_Fires)
#
# NameError: name 'AL_Fires' is not defined

# %%
AL_Fires = statesList.get_group('Alabama')
AK_Fires = statesList.get_group('Alaska')
AZ_Fires = statesList.get_group('Arizona')
AR_Fires = statesList.get_group('Arkansas')
CA_Fires = statesList.get_group('California')
CO_Fires = statesList.get_group('Colorado')
CT_Fires = statesList.get_group('Connecticut')
DE_Fires = statesList.get_group('Delaware')
FL_Fires = statesList.get_group('Florida')
GA_Fires = statesList.get_group('Georgia')
HI_Fires = statesList.get_group('Hawaii')
ID_Fires = statesList.get_group('Idaho')
IL_Fires = statesList.get_group('Illinois')
IN_Fires = statesList.get_group('Indiana')
IA_Fires = statesList.get_group('Iowa')
KS_Fires = statesList.get_group('Kansas')
KY_Fires = statesList.get_group('Kentucky')
LA_Fires = statesList.get_group('Louisiana')
ME_Fires = statesList.get_group('Maine')
MD_Fires = statesList.get_group('Maryland')
MA_Fires = statesList.get_group('Massachusetts')
MI_Fires = statesList.get_group('Michigan')
MN_Fires = statesList.get_group('Minnesota')
MS_Fires = statesList.get_group('Mississippi')
MO_Fires = statesList.get_group('Missouri')
MT_Fires = statesList.get_group('Montana')
NE_Fires = statesList.get_group('Nebraska')
NV_Fires = statesList.get_group('Nevada')
#NH_Fires = statesList.get_group('New Hampshire')
NJ_Fires = statesList.get_group('New Jersey')
NM_Fires = statesList.get_group('New Mexico')
NY_Fires = statesList.get_group('New York')
NC_Fires = statesList.get_group('North Carolina')
ND_Fires = statesList.get_group('North Dakota')
OH_Fires = statesList.get_group('Ohio')
OK_Fires = statesList.get_group('Oklahoma')
OR_Fires = statesList.get_group('Oregon')
PA_Fires = statesList.get_group('Pennsylvania')
RI_Fires = statesList.get_group('Rhode Island')
SC_Fires = statesList.get_group('South Carolina')
SD_Fires = statesList.get_group('South Dakota')
TN_Fires = statesList.get_group('Tennessee')
TX_Fires = statesList.get_group('Texas')
UT_Fires = statesList.get_group('Utah')
#VT_Fires = statesList.get_group('Vermont')
VA_Fires = statesList.get_group('Virginia')
WA_Fires = statesList.get_group('Washington')
WV_Fires = statesList.get_group('West Virginia')
WI_Fires = statesList.get_group('Wisconsin')
WY_Fires = statesList.get_group('Wyoming')

# %%
AL_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
AL_Fires['Year'] = AL_Fires.Date.dt.year
AL_Fires_Year = AL_Fires['Year'].value_counts().sort_index().cumsum().plot()
print(AL_Fires_Year)
AL_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Alabama')
AL_Fires_Year.plot()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# <ipython-input-9-467cd779b39e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AL_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-9-467cd779b39e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AL_Fires['Year'] = AL_Fires.Date.dt.year
# []

# %%
AK_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
AK_Fires['Year'] = AK_Fires.Date.dt.year
AK_Fires_Year = AK_Fires['Year'].value_counts().sort_index().cumsum().plot()
AK_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Alaska')
AK_Fires_Year.plot()
# Out:
# <ipython-input-10-6657eefb602e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AK_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-10-6657eefb602e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AK_Fires['Year'] = AK_Fires.Date.dt.year
# []

# %%
AZ_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
AZ_Fires['Year'] = AZ_Fires.Date.dt.year
AZ_Fires_Year = AZ_Fires['Year'].value_counts().sort_index().cumsum().plot()
AZ_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Arizona')
AZ_Fires_Year.plot()
# Out:
# <ipython-input-14-fd9800c6f3ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AZ_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-14-fd9800c6f3ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AZ_Fires['Year'] = AZ_Fires.Date.dt.year
# []

# %%
AR_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
AR_Fires['Year'] = AR_Fires.Date.dt.year
AR_Fires_Year = AR_Fires['Year'].value_counts().sort_index().cumsum().plot()
AR_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Arkansas')
AR_Fires_Year.plot()
# Out:
# <ipython-input-15-8792df7cd5df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AR_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-15-8792df7cd5df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AR_Fires['Year'] = AR_Fires.Date.dt.year
# []

# %%
CA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
CA_Fires['Year'] = CA_Fires.Date.dt.year
CA_Fires_Year = CA_Fires['Year'].value_counts().sort_index().cumsum().plot()
CA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In California')
CA_Fires_Year.plot()
# Out:
# <ipython-input-13-b606b4e33b00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-13-b606b4e33b00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_Fires['Year'] = CA_Fires.Date.dt.year
# []

# %%
CO_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
CO_Fires['Year'] = CO_Fires.Date.dt.year
CO_Fires_Year = CO_Fires['Year'].value_counts().sort_index().cumsum().plot()
CO_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Colorado')
CO_Fires_Year.plot()
# Out:
# <ipython-input-14-1854c19de508>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CO_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-14-1854c19de508>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CO_Fires['Year'] = CO_Fires.Date.dt.year
# []

# %%
CT_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
CT_Fires['Year'] = CT_Fires.Date.dt.year
CT_Fires_Year = CT_Fires['Year'].value_counts().sort_index().cumsum().plot()
CT_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Connecticut')
CT_Fires_Year.plot()
# Out:
# <ipython-input-15-278afcfa2567>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CT_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-15-278afcfa2567>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CT_Fires['Year'] = CT_Fires.Date.dt.year
# []

# %%
DE_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
DE_Fires['Year'] = DE_Fires.Date.dt.year
DE_Fires_Year = DE_Fires['Year'].value_counts().sort_index().cumsum().plot()
DE_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Delaware')
DE_Fires_Year.plot()
# Out:
# <ipython-input-16-3012843bfa85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DE_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-16-3012843bfa85>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DE_Fires['Year'] = DE_Fires.Date.dt.year
# []

# %%
FL_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
FL_Fires['Year'] = FL_Fires.Date.dt.year
FL_Fires_Year = FL_Fires['Year'].value_counts().sort_index().cumsum().plot()
FL_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Florida')
FL_Fires_Year.plot()
# Out:
# <ipython-input-17-117a92f6023c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FL_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-17-117a92f6023c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FL_Fires['Year'] = FL_Fires.Date.dt.year
# []

# %%
GA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
GA_Fires['Year'] = GA_Fires.Date.dt.year
GA_Fires_Year = GA_Fires['Year'].value_counts().sort_index().cumsum().plot()
GA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Georgia')
GA_Fires_Year.plot()
# Out:
# <ipython-input-18-7666b876d52b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-18-7666b876d52b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GA_Fires['Year'] = GA_Fires.Date.dt.year
# []

# %%
HI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
HI_Fires['Year'] = HI_Fires.Date.dt.year
HI_Fires_Year = HI_Fires['Year'].value_counts().sort_index().cumsum().plot()
HI_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Hawaii')
HI_Fires_Year.plot()
# Out:
# <ipython-input-19-3729d303cf2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-19-3729d303cf2e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HI_Fires['Year'] = HI_Fires.Date.dt.year
# []

# %%
ID_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
ID_Fires['Year'] = ID_Fires.Date.dt.year
ID_Fires_Year = ID_Fires['Year'].value_counts().sort_index().cumsum().plot()
ID_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Idaho')
ID_Fires_Year.plot()
# Out:
# <ipython-input-20-7da55b0710a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ID_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-20-7da55b0710a4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ID_Fires['Year'] = ID_Fires.Date.dt.year
# []

# %%
IL_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
IL_Fires['Year'] = IL_Fires.Date.dt.year
IL_Fires_Year = CT_Fires['Year'].value_counts().sort_index().cumsum().plot()
IL_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Illinois')
IL_Fires_Year.plot()
# Out:
# <ipython-input-21-84cbbefd6c04>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IL_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-21-84cbbefd6c04>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IL_Fires['Year'] = IL_Fires.Date.dt.year
# []

# %%
IN_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
IN_Fires['Year'] = IN_Fires.Date.dt.year
IN_Fires_Year = IN_Fires['Year'].value_counts().sort_index().cumsum().plot()
IN_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Indiana')
IN_Fires_Year.plot()
# Out:
# <ipython-input-22-ed17792cacf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IN_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-22-ed17792cacf4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IN_Fires['Year'] = IN_Fires.Date.dt.year
# []

# %%
IA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
IA_Fires['Year'] = IA_Fires.Date.dt.year
IA_Fires_Year = IA_Fires['Year'].value_counts().sort_index().cumsum().plot()
IA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Iowa')
IA_Fires_Year.plot()
# Out:
# <ipython-input-23-75587df2045d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-23-75587df2045d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IA_Fires['Year'] = IA_Fires.Date.dt.year
# []

# %%
KS_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
KS_Fires['Year'] = KS_Fires.Date.dt.year
KS_Fires_Year = KS_Fires['Year'].value_counts().sort_index().cumsum().plot()
KS_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Kansas')
KS_Fires_Year.plot()
# Out:
# <ipython-input-24-c2389fa71ddf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KS_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-24-c2389fa71ddf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KS_Fires['Year'] = KS_Fires.Date.dt.year
# []

# %%
KY_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
KY_Fires['Year'] = KY_Fires.Date.dt.year
KY_Fires_Year = KY_Fires['Year'].value_counts().sort_index().cumsum().plot()
KY_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Kentucky')
KY_Fires_Year.plot()
# Out:
# <ipython-input-25-cdea010adb93>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KY_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-25-cdea010adb93>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KY_Fires['Year'] = KY_Fires.Date.dt.year
# []

# %%
LA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
LA_Fires['Year'] = LA_Fires.Date.dt.year
LA_Fires_Year = LA_Fires['Year'].value_counts().sort_index().cumsum().plot()
LA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Louisiana')
LA_Fires_Year.plot()
# Out:
# <ipython-input-26-f2e6677a1819>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-26-f2e6677a1819>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LA_Fires['Year'] = LA_Fires.Date.dt.year
# []

# %%
ME_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
ME_Fires['Year'] = ME_Fires.Date.dt.year
ME_Fires_Year = ME_Fires['Year'].value_counts().sort_index().cumsum().plot()
ME_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Maine')
ME_Fires_Year.plot()
# Out:
# <ipython-input-27-78fa858a43f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ME_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-27-78fa858a43f1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ME_Fires['Year'] = ME_Fires.Date.dt.year
# []

# %%
MD_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MD_Fires['Year'] = MD_Fires.Date.dt.year
MD_Fires_Year = MD_Fires['Year'].value_counts().sort_index().cumsum().plot()
MD_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Maryland')
MD_Fires_Year.plot()
# Out:
# <ipython-input-28-905fb7e5806f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MD_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-28-905fb7e5806f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MD_Fires['Year'] = MD_Fires.Date.dt.year
# []

# %%
MA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MA_Fires['Year'] = MA_Fires.Date.dt.year
MA_Fires_Year = MA_Fires['Year'].value_counts().sort_index().cumsum().plot()
MA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Massachusetts')
MA_Fires_Year.plot()
# Out:
# <ipython-input-29-1d84ee934b51>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-29-1d84ee934b51>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MA_Fires['Year'] = MA_Fires.Date.dt.year
# []

# %%
MI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MI_Fires['Year'] = MI_Fires.Date.dt.year
MI_Fires_Year = MI_Fires['Year'].value_counts().sort_index().cumsum().plot()
MI_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Michigan')
MI_Fires_Year.plot()
# Out:
# <ipython-input-30-923ab7c49f50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-30-923ab7c49f50>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MI_Fires['Year'] = MI_Fires.Date.dt.year
# []

# %%
MN_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MN_Fires['Year'] = MN_Fires.Date.dt.year
MN_Fires_Year = MN_Fires['Year'].value_counts().sort_index().cumsum().plot()
MN_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Minnesota')
MN_Fires_Year.plot()
# Out:
# <ipython-input-31-bbbd5a36ba5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MN_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-31-bbbd5a36ba5a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MN_Fires['Year'] = MN_Fires.Date.dt.year
# []

# %%
MS_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MS_Fires['Year'] = MS_Fires.Date.dt.year
MS_Fires_Year = MS_Fires['Year'].value_counts().sort_index().cumsum().plot()
MS_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Mississippi')
MS_Fires_Year.plot()
# Out:
# <ipython-input-32-9bbf0ff4a33e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MS_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-32-9bbf0ff4a33e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MS_Fires['Year'] = MS_Fires.Date.dt.year
# []

# %%
MO_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MO_Fires['Year'] = MO_Fires.Date.dt.year
MO_Fires_Year = MO_Fires['Year'].value_counts().sort_index().cumsum().plot()
MO_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Missouri')
MO_Fires_Year.plot()
# Out:
# <ipython-input-33-ced6b5de5f9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MO_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-33-ced6b5de5f9b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MO_Fires['Year'] = MO_Fires.Date.dt.year
# []

# %%
MT_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
MT_Fires['Year'] = MT_Fires.Date.dt.year
MT_Fires_Year = MT_Fires['Year'].value_counts().sort_index().cumsum().plot()
MT_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Montana')
MT_Fires_Year.plot()
# Out:
# <ipython-input-34-c313ad4bda88>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MT_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-34-c313ad4bda88>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MT_Fires['Year'] = MT_Fires.Date.dt.year
# []

# %%
NE_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
NE_Fires['Year'] = NE_Fires.Date.dt.year
NE_Fires_Year = NE_Fires['Year'].value_counts().sort_index().cumsum().plot()
NE_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Nebraska')
NE_Fires_Year.plot()
# Out:
# <ipython-input-35-793b8b3577db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NE_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-35-793b8b3577db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NE_Fires['Year'] = NE_Fires.Date.dt.year
# []

# %%
NV_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
NV_Fires['Year'] = NV_Fires.Date.dt.year
NV_Fires_Year = NV_Fires['Year'].value_counts().sort_index().cumsum().plot()
NV_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Nevada')
NV_Fires_Year.plot()
# Out:
# <ipython-input-36-74fe260aa238>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NV_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-36-74fe260aa238>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NV_Fires['Year'] = NV_Fires.Date.dt.year
# []

# %%
NJ_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
NJ_Fires['Year'] = NJ_Fires.Date.dt.year
NJ_Fires_Year = NJ_Fires['Year'].value_counts().sort_index().cumsum().plot()
NJ_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In New Jersey')
NJ_Fires_Year.plot()
# Out:
# <ipython-input-37-88ac31f251ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NJ_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-37-88ac31f251ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NJ_Fires['Year'] = NJ_Fires.Date.dt.year
# []

# %%
NM_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
NM_Fires['Year'] = NM_Fires.Date.dt.year
NM_Fires_Year = NM_Fires['Year'].value_counts().sort_index().cumsum().plot()
NM_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In New Mexico')
NM_Fires_Year.plot()
# Out:
# <ipython-input-38-d1c5d3cdd5bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NM_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-38-d1c5d3cdd5bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NM_Fires['Year'] = NM_Fires.Date.dt.year
# []

# %%
NY_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
NY_Fires['Year'] = NY_Fires.Date.dt.year
NY_Fires_Year = NY_Fires['Year'].value_counts().sort_index().cumsum().plot()
NY_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In New York')
NY_Fires_Year.plot()
# Out:
# <ipython-input-39-a67c9c7a70b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NY_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-39-a67c9c7a70b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NY_Fires['Year'] = NY_Fires.Date.dt.year
# []

# %%
NC_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
NC_Fires['Year'] = NC_Fires.Date.dt.year
NC_Fires_Year = NC_Fires['Year'].value_counts().sort_index().cumsum().plot()
NC_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In North Carolina')
NC_Fires_Year.plot()
# Out:
# <ipython-input-40-66542a0a5650>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NC_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-40-66542a0a5650>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NC_Fires['Year'] = NC_Fires.Date.dt.year
# []

# %%
ND_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
ND_Fires['Year'] = ND_Fires.Date.dt.year
ND_Fires_Year = ND_Fires['Year'].value_counts().sort_index().cumsum().plot()
ND_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In North Dakota')
ND_Fires_Year.plot()
# Out:
# <ipython-input-41-7ffd7d17e0ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ND_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-41-7ffd7d17e0ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ND_Fires['Year'] = ND_Fires.Date.dt.year
# []

# %%
OH_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
OH_Fires['Year'] = OH_Fires.Date.dt.year
OH_Fires_Year = OH_Fires['Year'].value_counts().sort_index().cumsum().plot()
OH_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Ohio')
OH_Fires_Year.plot()
# Out:
# <ipython-input-42-7a6ce9a62a81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OH_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-42-7a6ce9a62a81>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OH_Fires['Year'] = OH_Fires.Date.dt.year
# []

# %%
OK_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
OK_Fires['Year'] = OK_Fires.Date.dt.year
OK_Fires_Year = OK_Fires['Year'].value_counts().sort_index().cumsum().plot()
OK_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Oklahoma')
OK_Fires_Year.plot()
# Out:
# <ipython-input-43-4d3849ee82c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OK_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-43-4d3849ee82c6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OK_Fires['Year'] = OK_Fires.Date.dt.year
# []

# %%
OR_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
OR_Fires['Year'] = OR_Fires.Date.dt.year
OR_Fires_Year = OR_Fires['Year'].value_counts().sort_index().cumsum().plot()
OR_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Oregon')
OR_Fires_Year.plot()
# Out:
# <ipython-input-44-d62a30ae94ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OR_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-44-d62a30ae94ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OR_Fires['Year'] = OR_Fires.Date.dt.year
# []

# %%
PA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
PA_Fires['Year'] = PA_Fires.Date.dt.year
PA_Fires_Year = PA_Fires['Year'].value_counts().sort_index().cumsum().plot()
PA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Pennsylvania')
PA_Fires_Year.plot()
# Out:
# <ipython-input-45-bac7fb9b1122>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-45-bac7fb9b1122>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PA_Fires['Year'] = PA_Fires.Date.dt.year
# []

# %%
RI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
RI_Fires['Year'] = RI_Fires.Date.dt.year
RI_Fires_Year = RI_Fires['Year'].value_counts().sort_index().cumsum().plot()
RI_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Rhode Island')
RI_Fires_Year.plot()
# Out:
# <ipython-input-46-75570d254fca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-46-75570d254fca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RI_Fires['Year'] = RI_Fires.Date.dt.year
# []

# %%
SC_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
SC_Fires['Year'] = SC_Fires.Date.dt.year
SC_Fires_Year = SC_Fires['Year'].value_counts().sort_index().cumsum().plot()
SC_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In South Carolina')
SC_Fires_Year.plot()
# Out:
# <ipython-input-47-3a4d129be24a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SC_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-47-3a4d129be24a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SC_Fires['Year'] = SC_Fires.Date.dt.year
# []

# %%
SD_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
SD_Fires['Year'] = SD_Fires.Date.dt.year
SD_Fires_Year = SD_Fires['Year'].value_counts().sort_index().cumsum().plot()
SD_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In South Dakota')
SD_Fires_Year.plot()
# Out:
# <ipython-input-48-e981fe0cabdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SD_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-48-e981fe0cabdb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SD_Fires['Year'] = SD_Fires.Date.dt.year
# []

# %%
TN_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
TN_Fires['Year'] = TN_Fires.Date.dt.year
TN_Fires_Year = TN_Fires['Year'].value_counts().sort_index().cumsum().plot()
TN_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Tennessee')
TN_Fires_Year.plot()
# Out:
# <ipython-input-49-4df0440799a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TN_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-49-4df0440799a1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TN_Fires['Year'] = TN_Fires.Date.dt.year
# []

# %%
TX_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
TX_Fires['Year'] = TX_Fires.Date.dt.year
TX_Fires_Year = TX_Fires['Year'].value_counts().sort_index().cumsum().plot()
TX_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Texas')
TX_Fires_Year.plot()
# Out:
# <ipython-input-50-2169cfb4f113>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TX_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-50-2169cfb4f113>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TX_Fires['Year'] = TX_Fires.Date.dt.year
# []

# %%
UT_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
UT_Fires['Year'] = UT_Fires.Date.dt.year
UT_Fires_Year = UT_Fires['Year'].value_counts().sort_index().cumsum().plot()
UT_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Utah')
UT_Fires_Year.plot()
# Out:
# <ipython-input-51-d639b602db8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UT_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-51-d639b602db8c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UT_Fires['Year'] = UT_Fires.Date.dt.year
# []

# %%
VA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
VA_Fires['Year'] = VA_Fires.Date.dt.year
VA_Fires_Year = VA_Fires['Year'].value_counts().sort_index().cumsum().plot()
VA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Virginia')
VA_Fires_Year.plot()
# Out:
# <ipython-input-52-bf9f94b7ce59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-52-bf9f94b7ce59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VA_Fires['Year'] = VA_Fires.Date.dt.year
# []

# %%
WA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
WA_Fires['Year'] = WA_Fires.Date.dt.year
WA_Fires_Year = WA_Fires['Year'].value_counts().sort_index().cumsum().plot()
WA_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Washington')
WA_Fires_Year.plot()
# Out:
# <ipython-input-53-499d91baa55a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-53-499d91baa55a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WA_Fires['Year'] = WA_Fires.Date.dt.year
# []

# %%
WV_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
WV_Fires['Year'] = WV_Fires.Date.dt.year
WV_Fires_Year = WV_Fires['Year'].value_counts().sort_index().cumsum().plot()
WV_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In West Virginia')
WV_Fires_Year.plot()
# Out:
# <ipython-input-54-3cbf1a68417a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WV_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-54-3cbf1a68417a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WV_Fires['Year'] = WV_Fires.Date.dt.year
# []

# %%
WI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
WI_Fires['Year'] = WI_Fires.Date.dt.year
WI_Fires_Year = WI_Fires['Year'].value_counts().sort_index().cumsum().plot()
WI_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Wisconsin')
WI_Fires_Year.plot()
# Out:
# <ipython-input-55-81a7ebe3a24f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WI_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-55-81a7ebe3a24f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WI_Fires['Year'] = WI_Fires.Date.dt.year
# []

# %%
WY_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
WY_Fires['Year'] = WY_Fires.Date.dt.year
WY_Fires_Year = WY_Fires['Year'].value_counts().sort_index().cumsum().plot()
WY_Fires_Year.set_xticks([2013, 2014, 2015, 2016, 2017])
plt.xlabel('Year')
plt.ylabel('Number of Fires')
plt.title('Number of Fires Per Year In Wyoming')
WY_Fires_Year.plot()
# Out:
# <ipython-input-56-b33e3088998f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WY_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-56-b33e3088998f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WY_Fires['Year'] = WY_Fires.Date.dt.year
# []

# %%
CA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
CA_Fires['Year'] = CA_Fires.Date.dt.year
CA_Fires_Year = CA_Fires['Year'].value_counts().sort_index().cumsum()
CA_Fires_Year_df = pd.DataFrame(data = CA_Fires_Year)
CA_Fires_Year_df.reset_index(inplace=True)
CA_Fires_Year_df = CA_Fires_Year_df.rename(columns = {'index': 'Year'})
CA_Fires_Year_df.columns = ["Year", "Fires"]
print(CA_Fires_Year_df)
corr = CA_Fires_Year_df.corr(method = "pearson")
print(corr)
plt.matshow(corr)
# Out:
#    Year  Fires
# 0  2013    660
# 1  2014   1211
# 2  2015   1855
# 3  2016   2282
# 4  2017   2387
#            Year     Fires
# Year   1.000000  0.975153
# Fires  0.975153  1.000000
# <ipython-input-16-5286ead04a8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_Fires['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# <ipython-input-16-5286ead04a8d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_Fires['Year'] = CA_Fires.Date.dt.year
